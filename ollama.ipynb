# %%
import subprocess,ollama

####starts ollama server

subprocess.run(["ollama", "serve"], check=True)
###collects host address for notebook
host = subprocess.check_output(["ollama", "host"], text=True).strip()
print("ollama host reports:", host)
###jupyter notebook requires http to be in front of host, this line adds http to host
if not host.startswith("http://") and not host.startswith("https://"):
    host = "http://" + host
print("ollama host for notebook:", host)
# Out:
# [ollama] Existing server already running at 127.0.0.1:30281
# [ollama] Skipping new launch.
# ollama host reports: 127.0.0.1:30281
# ollama host for notebook: http://127.0.0.1:30281

# %% [markdown]
# Creates the ollama server for python to access

# %%
##imports client to save host address
from ollama import Client
client = Client(host=host)

# %%
###prompts model using saved host address
resp = client.generate(
    model="llama3.1",
    prompt="wite 10 haikus about shel silverstein",
    options={
        "temperature":10.0,
        "num_ctx": 4096,
        "top_p": 0.1,
        "num_predict": 10000,
    },
)

print(resp["response"])
# Out:
# Here are ten haikus about Shel Silverstein:
#
# Whimsy in his words
# Laughter and tears entwined deep
# Silverstein's delight
#
# Giraffes and giants roam
# In his world of wonder, dreams
# Take on a new shape
#
# Poet of the young heart
# Telling truths with gentle humor
# Making us smile wide
#
# The Giving Tree's sad tale
# A story of love and loss told
# Through Silverstein's eyes
#
# Unlikely heroes rise
# From his pages, we find courage
# In the most unlikely
#
# Foghorn Leghorn's pride
# Boasts and boasts, but learns to see
# Humility's value
#
# Silverstein's world view
# A place where fantasy meets
# Reality's edge
#
# The Boa Constrictor
# Loves to eat its favorite food
# But then it gets a taste
#
# In the land of make-believe
# Where wild things roam and play free
# We find our own wild heart
#
# Silverstein's legacy
#  Lives on in his words, still
# Making us laugh, cry

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------
# **FOR EXAMPLE 3**
# ollama variables:
# - temperature: 0-1-2,
#     - increasing values increases creativity and volatility
# - top_p: 0-1
#     - increasing value increases variability in word choice
# - num_ctx = context length: 100+
#     - increases length of allowed input
# - num_predict = max output length: 100+
#     - increases length of allowed output

# %% [markdown]
# #**Play with variables here, change the prompt, etc**

# %%
resp = client.generate(
    model="llama3.1",
    prompt="ENTER DESIRED PROMPT",
    options={
        "temperature":XX ,
        "num_ctx":2048 ,
        "top_p":XX ,
        "num_predict":XX ,  # cap generation length
    },
)

print(resp["response"])

# %% [markdown]
# #**run modified LLM here**

# %%
resp = client.generate(model="my_model_<netid>, prompt="<your_prompt>")
print(resp["response"])
# Out:
# Hello! Is there something I can help you with or would you like to chat?
