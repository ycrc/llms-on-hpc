# %%
import subprocess,ollama

####starts ollama server

subprocess.run(["ollama", "serve"], check=True)
###collects host address for notebook
host = subprocess.check_output(["ollama", "host"], text=True).strip()
print("ollama host reports:", host)
###jupyter notebook requires http to be in front of host, this line adds http to host
if not host.startswith("http://") and not host.startswith("https://"):
    host = "http://" + host
print("ollama host for notebook:", host)
# Out:
# [ollama] Background server target: 127.0.0.1:28533
#          Host file: /tmp/ollama_hpcllm_mrr68_3498352_gpu0/host
#          Log file : /tmp/ollama_hpcllm_mrr68_3498352_gpu0/ollama-serve.log
# ollama host reports: 127.0.0.1:28533
# ollama host for notebook: http://127.0.0.1:28533

# %% [markdown]
# Creates the ollama server for python to access

# %%
##imports client to save host address
from ollama import Client
client = Client(host=host)

# %%
###prompts model using saved host address
resp = client.generate(
    model="llama3.1:8b",
    prompt="Define an experiment to measure the effect of caffeine on the ability for a student to focus",
    options={
        "temperature": 0.1,
        "num_ctx": 4096,
        "top_p": 1.0,
        "num_predict": 10000,
    },
)

print(resp["response"])
# Out:
# Here's a proposed experiment design to measure the effect of caffeine on a student's ability to focus:
#
# **Title:** The Effect of Caffeine on Focus and Concentration in Students
#
# **Hypothesis:**
#
# * Null Hypothesis (H0): There is no significant difference in focus and concentration between students who consume caffeine and those who do not.
# * Alternative Hypothesis (H1): Students who consume caffeine will exhibit improved focus and concentration compared to those who do not.
#
# **Experimental Design:**
#
# This experiment will be a within-subjects design, where each participant serves as their own control. The experiment will consist of two conditions:
#
# 1. **Caffeine Condition:** Participants will consume a standard dose of caffeine (e.g., 200mg) in the form of a capsule or tablet.
# 2. **Placebo Condition:** Participants will receive an identical-looking placebo capsule or tablet with no caffeine.
#
# **Participants:**
#
# * A group of 20-30 students from a university or college setting, aged 18-25 years old
# * Students who are regular coffee drinkers and have not consumed any caffeine for at least 12 hours prior to the experiment
#
# **Procedure:**
#
# 1. **Pre-test:** Participants will complete a baseline focus and concentration assessment (e.g., a standardized attention task) before consuming either the caffeine or placebo.
# 2. **Caffeine/Placebo Administration:** Participants will be randomly assigned to either the caffeine or placebo condition. They will consume their assigned substance in a controlled environment, with a timer set for 30 minutes.
# 3. **Post-test:** After 30 minutes, participants will complete another focus and concentration assessment identical to the pre-test.
# 4. **Repeated Measures:** The experiment will be repeated on two separate days, with participants switching conditions (e.g., caffeine one day, placebo the next).
#
# **Focus and Concentration Assessment:**
#
# * A standardized attention task, such as:
# 	+ Stroop Task: Participants will be shown a series of words printed in different colors and asked to identify the color of the ink.
# 	+ N-Back Task: Participants will be presented with a sequence of numbers or letters and asked to identify when a stimulus appears that is identical to one presented n items earlier (e.g., 2-back).
# * Reaction time and accuracy measures will be recorded for each task.
#
# **Data Analysis:**
#
# * Descriptive statistics (means, standard deviations) will be calculated for each condition.
# * A repeated-measures ANOVA will be used to compare the focus and concentration scores between conditions (caffeine vs. placebo).
# * Post-hoc tests (e.g., paired t-tests) will be conducted to examine differences in performance between conditions.
#
# **Control Variables:**
#
# * Participants' sleep patterns, exercise habits, and nutrition will be controlled for by asking participants to maintain their usual routines during the experiment.
# * The experiment will take place at a consistent time of day to minimize circadian rhythm effects on focus and concentration.
#
# **Limitations:**
#
# * This study is limited to a small sample size and may not generalize to other populations (e.g., older adults, individuals with sleep disorders).
# * The caffeine dose used in this study may not be representative of typical consumption patterns.
# * Individual differences in sensitivity to caffeine may affect results.
#
# This experiment design aims to provide a clear and controlled assessment of the effect of caffeine on focus and concentration. However, it is essential to consider potential limitations and control variables to ensure the validity and reliability of the findings.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------
# **FOR EXAMPLE 3**
# ollama variables:
# - temperature: 0-1-2,
#     - increasing values increases creativity and volatility
# - top_p: 0-1
#     - increasing value increases variability in word choice
# - num_ctx = context length: 100+
#     - increases length of allowed input
# - num_predict = max output length: 100+
#     - increases length of allowed output

# %% [markdown]
# #**Play with variables here, change the prompt, etc**

# %%
resp = client.generate(
    model="llama3.1:8b",
    prompt="ENTER DESIRED PROMPT",
    options={
        "temperature":XX ,
        "num_ctx":2048 ,
        "top_p":XX ,
        "num_predict":XX ,  # cap generation length
    },
)

print(resp["response"])

# %% [markdown]
# #**run modified LLM here**

# %%
resp = client.generate(model="my_model_<netid>, prompt="<your_prompt>")
print(resp["response"])
# Out:
# Hello! Is there something I can help you with or would you like to chat?
